# %%
 import skimage
import os
from skimage import io
from skimage.color import rgb2gray
from skimage import data
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import shutil


a=io.imread(r"C:\Users\Shreyas I\Desktop\royce.jpg")
io.imshow(a)
print(a.shape)
x,y,z=np.shape(a)


for i in range(1,x):
    for j in range(1,y):
        
            if i>300 and i<500:
                if j>300 and j<500:
                   
                    a[i][j][0]=255
                    a[i][j][1]=0
                    a[i][j][2]=0
io.imshow(a)
io.imsave('test.png',a)
src ="C:\\Users\\Shreyas I\\Anaconda3\\test.png"
dst ="C:\\Users\\Shreyas I\\Desktop\\task2"
shutil.move(src, dst)
# Out:
# (1080, 1920, 3)
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# <ipython-input-5-22ca484c1873> in <module>
#      29 src ="C:\\Users\\Shreyas I\\Anaconda3\\test.png"
#      30 dst ="C:\\Users\\Shreyas I\\Desktop\\task2"
# ---> 31 shutil.move(src, dst)
#      32
#      33
#
# ~\Anaconda3\lib\shutil.py in move(src, dst, copy_function)
#     553         real_dst = os.path.join(dst, _basename(src))
#     554         if os.path.exists(real_dst):
# --> 555             raise Error("Destination path '%s' already exists" % real_dst)
#     556     try:
#     557         os.rename(src, real_dst)
#
# Error: Destination path 'C:\Users\Shreyas I\Desktop\task2\test.png' already exists
